# %%
import torch
import tables
import os
import os,sys
import glob

import PIL
import numpy as np
from numpy.lib.stride_tricks import as_strided

import cv2
import matplotlib.pyplot as plt

from sklearn import model_selection
import random


seed = random.randrange(sys.maxsize) #get a random seed so that we can reproducibly do the cross validation setup
random.seed(seed) # set the seed
print(f"random seed (note down for reproducibility): {seed}")
# Out:
# random seed (note down for reproducibility): 6341798946737309275

# %%
patch_size=500 #size of the tiles to extract and save in the database, must be >= to training size
test_set_size=.1 # what percentage of the dataset should be used as a held out validation/testing set

classes=[0,1,2,3] #what classes we expect to have in the data, here we have only 2 classes but we could add additional classes and/or specify an index from which we would like to ignore

targetMag = 8
#17S050572_1A_L12 - 2018-03-20 13.09.26.ndpi Masked out because of too large to be saved in mag=8

dataname="melanoma_png"+"_"+str(targetMag)

baseMag = 20
file_ext= ".png"
mask_ext = ".png"
mask_pattern = "*"


imgdir = f"/home/yxz1826/downsampled/{targetMag}_group"
maskroot = os.environ["REMOTE"]+'/Skin/QupathOut/multi_mag'

maskdir = maskroot+f"/{targetMag:.1f}/"
pytable_root = '/mnt/ccipd_home/yxz1826/Skin/pytable'
print(maskdir)
print(imgdir)
print(dataname)
# Out:
# /mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/
# /home/yxz1826/downsampled/8_group
# melanoma_png_8

# %%
img_dtype = tables.UInt8Atom()  # dtype in which the images will be saved, this indicates that images will be saved as unsigned int 8 bit, i.e., [0,255]
filenameAtom = tables.StringAtom(itemsize=255) #create an atom to store the filename of the image, just incase we need it later, 
files=glob.glob(maskdir+mask_pattern+mask_ext) # create a list of the files, in this case we're only interested in files which have masks so we can use supervised learning

#create training and validation stages and split the files appropriately between them
phases={}
phases["train"],phases["val"]=next(iter(model_selection.ShuffleSplit(n_splits=10,test_size=test_set_size).split(files)))

#specify that we'll be saving 2 different image types to the database, an image and its associated masked
imgtypes=["img","mask"]

# %%
import readslide
from readslide import getThumbByMag
from readslide import ndpiAdaptor

# %%
##Define adaptor- contract of reading
#imageIOAdaptor = defaultIOAdaptor
from readslide import pngAdaptor

# %%
imageIOAdaptor = pngAdaptor


storage={} #holder for future pytables
temp_handle = {} #just in case exception raised

block_shape={} #block shape specifies what we'll be saving into the pytable array, here we assume that masks are 1d and images are 3d
block_shape["img"]= np.array((patch_size,patch_size,3))
block_shape["mask"]= np.array((patch_size,patch_size)) 

filters=tables.Filters(complevel=6, complib='zlib') #we can also specify filters, such as compression, to improve storage speed


for phase in phases.keys(): #now for each of the phases, we'll loop through the files
    print(phase)
    
    totals=np.zeros((2,len(classes))) # we can to keep counts of all the classes in for in particular training, since we 
    totals[0,:]=classes               # can later use this information to create better weights

    hdf5_file = tables.open_file(f"{pytable_root}/{dataname}_{phase}.pytable", mode='w') #open the respective pytable
    temp_handle[phase] = hdf5_file
    storage["filename"] = hdf5_file.create_earray(hdf5_file.root, 'filename', filenameAtom, (0,)) #create the array for storage
    
    for imgtype in imgtypes: #for each of the image types, in this case mask and image, we need to create the associated earray
        storage[imgtype]= hdf5_file.create_earray(hdf5_file.root, imgtype, img_dtype,  
                                                  shape=np.append([0],block_shape[imgtype]), 
                                                  chunkshape=np.append([1],block_shape[imgtype]),
                                                  filters=filters)
    count = 0
    for filei in phases[phase]: #now for each of the files
        fname=files[filei] 
        for imgtype in imgtypes:
            count = count +1
            print(count)
            io = imageIOAdaptor(imgtype,imgdir,fname,file_ext,classes,(targetMag,baseMag),totals)
            io_shape = np.array(io.shape) #get the final shape
           
            #the code below chops up the image into tiles of the appropriate shape, resulting in a 4D tensor
            #this code could be improved to take more samples, for example with a stride of 1/2 of the tile size to better cover the data
            new_shape = tuple(io_shape  // block_shape[imgtype]) + tuple(block_shape[imgtype])
            new_strides = tuple(io.strides * block_shape[imgtype]) + io.strides
           # print(io.dtype)
            #print("calc:",io_shape,block_shape[imgtype],io.strides)
           # print("new:",new_shape,new_strides)
            io_arr_out = as_strided(io, shape=new_shape, strides=new_strides)
            #print('pre_resize:',io_arr_out.shape)
            io_arr_out=io_arr_out.reshape(np.append([-1],block_shape[imgtype]))
            #save the 4D tensor to the table
            #print(io_arr_out.shape)
            storage[imgtype].append(io_arr_out)
            pass
            
        storage["filename"].append([fname for x in range(io_arr_out.shape[0])]) #add the filename to the storage array
        pass
    #lastely, we should store the number of pixels
    npixels=hdf5_file.create_carray(hdf5_file.root, 'numpixels', tables.Atom.from_dtype(totals.dtype), totals.shape)
    npixels[:]=totals
    print(hdf5_file.root.numpixels)
    hdf5_file.close()
pass
print("finish")
# Out:
# train
# 1
# imgMode:/home/yxz1826/downsampled/8_group/17S049691_1A_L1 - 2018-03-20 08.01.28.png
# 2
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049691_1A_L1 - 2018-03-20 08.01.28_mask.png
# 3
# imgMode:/home/yxz1826/downsampled/8_group/17S050297_4A_L12 - 2018-03-21 14.36.00.png
# 4
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050297_4A_L12 - 2018-03-21 14.36.00_mask.png
# 5
# imgMode:/home/yxz1826/downsampled/8_group/17Z024109_2A_L1 - 2018-03-22 18.09.33.png
# 6
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024109_2A_L1 - 2018-03-22 18.09.33_mask.png
# 7
# imgMode:/home/yxz1826/downsampled/8_group/17S050412_1A_L1 - 2018-03-21 14.57.01.png
# 8
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050412_1A_L1 - 2018-03-21 14.57.01_mask.png
# 9
# imgMode:/home/yxz1826/downsampled/8_group/17Z024398_1A-L123 - 2018-03-22 18.25.44.png
# 10
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024398_1A-L123 - 2018-03-22 18.25.44_mask.png
# 11
# imgMode:/home/yxz1826/downsampled/8_group/17Z017053_1A_L456 - 2018-03-23 15.25.57.png
# 12
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017053_1A_L456 - 2018-03-23 15.25.57_mask.png
# 13
# imgMode:/home/yxz1826/downsampled/8_group/17S049689_2A_L123 - 2018-03-20 07.59.03.png
# 14
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049689_2A_L123 - 2018-03-20 07.59.03_mask.png
# 15
# imgMode:/home/yxz1826/downsampled/8_group/17Z025019_1A_L456 - 2018-03-22 11.18.13.png
# 16
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z025019_1A_L456 - 2018-03-22 11.18.13_mask.png
# 17
# imgMode:/home/yxz1826/downsampled/8_group/17Z024068_2A_L123 - 2018-03-23 14.01.20.png
# 18
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024068_2A_L123 - 2018-03-23 14.01.20_mask.png
# 19
# imgMode:/home/yxz1826/downsampled/8_group/17Z017053_1A_L123 - 2018-03-23 15.23.45.png
# 20
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017053_1A_L123 - 2018-03-23 15.23.45_mask.png
# 21
# imgMode:/home/yxz1826/downsampled/8_group/17z023856_1A_L456 - 2018-03-23 13.34.25.png
# 22
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z023856_1A_L456 - 2018-03-23 13.34.25_mask.png
# 23
# imgMode:/home/yxz1826/downsampled/8_group/17S051235_1A_L456 - 2018-03-20 15.46.35.png
# 24
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051235_1A_L456 - 2018-03-20 15.46.35_mask.png
# 25
# imgMode:/home/yxz1826/downsampled/8_group/17S049863_1A_L1 - 2018-03-20 12.01.19.png
# 26
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049863_1A_L1 - 2018-03-20 12.01.19_mask.png
# 27
# imgMode:/home/yxz1826/downsampled/8_group/17z023749_1A_L123 - 2018-03-23 13.15.12.png
# 28
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z023749_1A_L123 - 2018-03-23 13.15.12_mask.png
# 29
# imgMode:/home/yxz1826/downsampled/8_group/17S049745_1A_L1 - 2018-03-20 11.04.11.png
# 30
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049745_1A_L1 - 2018-03-20 11.04.11_mask.png
# 31
# imgMode:/home/yxz1826/downsampled/8_group/17z033111_3A_L123 - 2018-03-27 15.28.45.png
# 32
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z033111_3A_L123 - 2018-03-27 15.28.45_mask.png
# 33
# imgMode:/home/yxz1826/downsampled/8_group/17Z033114_1A_L12 - 2018-03-27 15.44.48.png
# 34
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033114_1A_L12 - 2018-03-27 15.44.48_mask.png
# 35
# imgMode:/home/yxz1826/downsampled/8_group/17S049770_1A_L12 - 2018-03-20 11.26.45.png
# 36
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049770_1A_L12 - 2018-03-20 11.26.45_mask.png
# 37
# imgMode:/home/yxz1826/downsampled/8_group/17S050294_2A_L12 - 2018-03-20 12.49.47.png
# 38
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050294_2A_L12 - 2018-03-20 12.49.47_mask.png
# 39
# imgMode:/home/yxz1826/downsampled/8_group/17S050808_1A_L123 - 2018-03-20 13.40.01.png
# 40
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050808_1A_L123 - 2018-03-20 13.40.01_mask.png
# 41
# imgMode:/home/yxz1826/downsampled/8_group/17Z024059_1A_L123 - 2018-03-23 13.47.28.png
# 42
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024059_1A_L123 - 2018-03-23 13.47.28_mask.png
# 43
# imgMode:/home/yxz1826/downsampled/8_group/17Z024399_5A_L123 - 2018-03-22 18.39.27.png
# 44
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024399_5A_L123 - 2018-03-22 18.39.27_mask.png
# 45
# imgMode:/home/yxz1826/downsampled/8_group/17Z018608_1A_L123 - 2018-03-23 11.14.53.png
# 46
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018608_1A_L123 - 2018-03-23 11.14.53_mask.png
# 47
# imgMode:/home/yxz1826/downsampled/8_group/17z023853_1A_L1 - 2018-03-23 13.25.38.png
# 48
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z023853_1A_L1 - 2018-03-23 13.25.38_mask.png
# 49
# imgMode:/home/yxz1826/downsampled/8_group/17S050380_1A_L123 - 2018-03-21 14.51.19.png
# 50
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050380_1A_L123 - 2018-03-21 14.51.19_mask.png
# 51
# imgMode:/home/yxz1826/downsampled/8_group/17S049641_1A_L123 - 2018-03-20 07.37.40.png
# 52
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049641_1A_L123 - 2018-03-20 07.37.40_mask.png
# 53
# imgMode:/home/yxz1826/downsampled/8_group/17S051330_1A_L123 - 2018-03-20 16.35.50.png
# 54
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051330_1A_L123 - 2018-03-20 16.35.50_mask.png
# 55
# imgMode:/home/yxz1826/downsampled/8_group/17S051158_1A_L123 - 2018-03-20 15.08.34.png
# 56
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051158_1A_L123 - 2018-03-20 15.08.34_mask.png
# 57
# imgMode:/home/yxz1826/downsampled/8_group/17S051160_1A_HE - 2018-03-20 15.11.58.png
# 58
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051160_1A_HE - 2018-03-20 15.11.58_mask.png
# 59
# imgMode:/home/yxz1826/downsampled/8_group/17Z025019_1A_L123 - 2018-03-22 11.15.20.png
# 60
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z025019_1A_L123 - 2018-03-22 11.15.20_mask.png
# 61
# imgMode:/home/yxz1826/downsampled/8_group/17S049647_1A_L123 - 2018-03-20 07.51.36.png
# 62
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049647_1A_L123 - 2018-03-20 07.51.36_mask.png
# 63
# imgMode:/home/yxz1826/downsampled/8_group/17S049689_1A_L123 - 2018-03-20 07.56.34.png
# 64
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049689_1A_L123 - 2018-03-20 07.56.34_mask.png
# 65
# imgMode:/home/yxz1826/downsampled/8_group/17S049918_2A_L123 - 2018-03-20 12.12.42.png
# 66
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049918_2A_L123 - 2018-03-20 12.12.42_mask.png
# 67
# imgMode:/home/yxz1826/downsampled/8_group/17Z024080_1A_L1 - 2018-03-22 17.59.48.png
# 68
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024080_1A_L1 - 2018-03-22 17.59.48_mask.png
# 69
# imgMode:/home/yxz1826/downsampled/8_group/17S051560_1A_L12 - 2018-03-20 21.20.29.png
# 70
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051560_1A_L12 - 2018-03-20 21.20.29_mask.png
# 71
# imgMode:/home/yxz1826/downsampled/8_group/17Z032901_3A_L123 - 2018-03-20 09.59.57.png
# 72
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032901_3A_L123 - 2018-03-20 09.59.57_mask.png
# 73
# imgMode:/home/yxz1826/downsampled/8_group/17Z024763_2A_L123 - 2018-03-22 16.26.20.png
# 74
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024763_2A_L123 - 2018-03-22 16.26.20_mask.png
# 75
# imgMode:/home/yxz1826/downsampled/8_group/17Z024549_2A_L123 - 2018-03-22 16.50.34.png
# 76
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024549_2A_L123 - 2018-03-22 16.50.34_mask.png
# 77
# imgMode:/home/yxz1826/downsampled/8_group/17Z024652_2A_L123 - 2018-03-22 16.13.19.png
# 78
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024652_2A_L123 - 2018-03-22 16.13.19_mask.png
# 79
# imgMode:/home/yxz1826/downsampled/8_group/17S049647_2A_L123 - 2018-03-20 07.53.53.png
# 80
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049647_2A_L123 - 2018-03-20 07.53.53_mask.png
# 81
# imgMode:/home/yxz1826/downsampled/8_group/17Z023746_1A_L123 - 2018-03-23 12.56.28.png
# 82
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z023746_1A_L123 - 2018-03-23 12.56.28_mask.png
# 83
# imgMode:/home/yxz1826/downsampled/8_group/17Z033106_1A_L123 - 2018-03-26 17.20.34.png
# 84
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033106_1A_L123 - 2018-03-26 17.20.34_mask.png
# 85
# imgMode:/home/yxz1826/downsampled/8_group/17S049827_1A_L12 - 2018-03-20 11.55.38.png
# 86
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049827_1A_L12 - 2018-03-20 11.55.38_mask.png
# 87
# imgMode:/home/yxz1826/downsampled/8_group/17S049764_1A_L12 - 2018-03-20 11.23.59.png
# 88
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049764_1A_L12 - 2018-03-20 11.23.59_mask.png
# 89
# imgMode:/home/yxz1826/downsampled/8_group/17Z018025_1A_L123 - 2018-03-24 13.45.17.png
# 90
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018025_1A_L123 - 2018-03-24 13.45.17_mask.png
# 91
# imgMode:/home/yxz1826/downsampled/8_group/17Z017322 1A L456.png
# 92
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017322 1A L456_mask.png
# 93
# imgMode:/home/yxz1826/downsampled/8_group/17Z018025_1A_STEPL456 - 2018-03-24 13.41.27.png
# 94
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018025_1A_STEPL456 - 2018-03-24 13.41.27_mask.png
# 95
# imgMode:/home/yxz1826/downsampled/8_group/17Z024650_3A_L123 - 2018-03-22 16.00.45.png
# 96
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024650_3A_L123 - 2018-03-22 16.00.45_mask.png
# 97
# imgMode:/home/yxz1826/downsampled/8_group/17S050002_2A_L12 - 2018-03-20 12.22.37.png
# 98
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050002_2A_L12 - 2018-03-20 12.22.37_mask.png
# 99
# imgMode:/home/yxz1826/downsampled/8_group/17z017031_1a_l123 - 2018-03-23 14.58.04.png
# 100
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z017031_1a_l123 - 2018-03-23 14.58.04_mask.png
# 101
# imgMode:/home/yxz1826/downsampled/8_group/17Z023750_1A_L1 - 2018-03-23 13.19.12.png
# 102
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z023750_1A_L1 - 2018-03-23 13.19.12_mask.png
# 103
# imgMode:/home/yxz1826/downsampled/8_group/17S050556_1A_L123 - 2018-03-20 14.16.16.png
# 104
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050556_1A_L123 - 2018-03-20 14.16.16_mask.png
# 105
# imgMode:/home/yxz1826/downsampled/8_group/17Z033044_1A_L12 - 2018-03-26 17.14.21.png
# 106
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033044_1A_L12 - 2018-03-26 17.14.21_mask.png
# 107
# imgMode:/home/yxz1826/downsampled/8_group/17S050294_1A_L12 - 2018-03-20 12.57.33.png
# 108
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050294_1A_L12 - 2018-03-20 12.57.33_mask.png
# 109
# imgMode:/home/yxz1826/downsampled/8_group/17S051235_2A_L789 - 2018-03-20 15.54.27.png
# 110
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051235_2A_L789 - 2018-03-20 15.54.27_mask.png
# 111
# imgMode:/home/yxz1826/downsampled/8_group/17Z024068_3A_L123 - 2018-03-23 14.04.00.png
# 112
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024068_3A_L123 - 2018-03-23 14.04.00_mask.png
# 113
# imgMode:/home/yxz1826/downsampled/8_group/17Z017036_1A_L456 - 2018-03-23 15.15.18.png
# 114
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017036_1A_L456 - 2018-03-23 15.15.18_mask.png
# 115
# imgMode:/home/yxz1826/downsampled/8_group/17Z017474_1A_L123 - 2018-03-23 17.23.12.png
# 116
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017474_1A_L123 - 2018-03-23 17.23.12_mask.png
# 117
# imgMode:/home/yxz1826/downsampled/8_group/17Z024567_1A_L123 - 2018-03-22 16.58.19.png
# 118
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024567_1A_L123 - 2018-03-22 16.58.19_mask.png
# 119
# imgMode:/home/yxz1826/downsampled/8_group/17Z025014_1A_L1 - 2018-03-22 16.29.01.png
# 120
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z025014_1A_L1 - 2018-03-22 16.29.01_mask.png
# 121
# imgMode:/home/yxz1826/downsampled/8_group/17Z032831_1A_L12 - 2018-03-20 09.30.26.png
# 122
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032831_1A_L12 - 2018-03-20 09.30.26_mask.png
# 123
# imgMode:/home/yxz1826/downsampled/8_group/17Z032980_1A_L2 - 2018-03-26 16.59.31.png
# 124
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032980_1A_L2 - 2018-03-26 16.59.31_mask.png
# 125
# imgMode:/home/yxz1826/downsampled/8_group/17Z033110_1A_L123 - 2018-03-26 17.39.04.png
# 126
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033110_1A_L123 - 2018-03-26 17.39.04_mask.png
# 127
# imgMode:/home/yxz1826/downsampled/8_group/17S051558_1A_L123 - 2018-03-20 21.17.52.png
# 128
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051558_1A_L123 - 2018-03-20 21.17.52_mask.png
# 129
# imgMode:/home/yxz1826/downsampled/8_group/17S051389_1A_L456 - 2018-03-20 20.41.15.png
# 130
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051389_1A_L456 - 2018-03-20 20.41.15_mask.png
# 131
# imgMode:/home/yxz1826/downsampled/8_group/17Z024567_2A_L123 - 2018-03-22 17.01.22.png
# 132
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024567_2A_L123 - 2018-03-22 17.01.22_mask.png
# 133
# imgMode:/home/yxz1826/downsampled/8_group/17z024698_1A_L1 - 2018-03-22 16.18.47.png
# 134
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z024698_1A_L1 - 2018-03-22 16.18.47_mask.png
# 135
# imgMode:/home/yxz1826/downsampled/8_group/17Z018720_1A_L123 - 2018-03-24 14.42.12.png
# 136
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018720_1A_L123 - 2018-03-24 14.42.12_mask.png
# 137
# imgMode:/home/yxz1826/downsampled/8_group/17Z024061_1A_L123 - 2018-03-23 13.50.13.png
# 138
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024061_1A_L123 - 2018-03-23 13.50.13_mask.png
# 139
# imgMode:/home/yxz1826/downsampled/8_group/17z024543_1A_L123 - 2018-03-22 16.42.23.png
# 140
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z024543_1A_L123 - 2018-03-22 16.42.23_mask.png
# 141
# imgMode:/home/yxz1826/downsampled/8_group/17S050555_1A_L123 - 2018-03-20 13.03.57.png
# 142
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050555_1A_L123 - 2018-03-20 13.03.57_mask.png
# 143
# imgMode:/home/yxz1826/downsampled/8_group/17Z024073_2A_L123 - 2018-03-22 17.45.09.png
# 144
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024073_2A_L123 - 2018-03-22 17.45.09_mask.png
# 145
# imgMode:/home/yxz1826/downsampled/8_group/17S051542_1A_L12 - 2018-03-20 20.53.27.png
# 146
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051542_1A_L12 - 2018-03-20 20.53.27_mask.png
# 147
# imgMode:/home/yxz1826/downsampled/8_group/17S050380_2A_L123 - 2018-03-21 14.54.06.png
# 148
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050380_2A_L123 - 2018-03-21 14.54.06_mask.png
# 149
# imgMode:/home/yxz1826/downsampled/8_group/17Z024650_2A_L123 - 2018-03-22 16.02.49.png
# 150
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024650_2A_L123 - 2018-03-22 16.02.49_mask.png
# 151
# imgMode:/home/yxz1826/downsampled/8_group/17Z024399_1A_L123 - 2018-03-22 18.28.23.png
# 152
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024399_1A_L123 - 2018-03-22 18.28.23_mask.png
# 153
# imgMode:/home/yxz1826/downsampled/8_group/17S049745_1A_L2 - 2018-03-20 11.01.16.png
# 154
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049745_1A_L2 - 2018-03-20 11.01.16_mask.png
# 155
# imgMode:/home/yxz1826/downsampled/8_group/17Z019199_1A_L1 - 2018-03-23 10.30.39.png
# 156
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z019199_1A_L1 - 2018-03-23 10.30.39_mask.png
# 157
# imgMode:/home/yxz1826/downsampled/8_group/17Z025017_1A_L1 - 2018-03-22 16.38.36.png
# 158
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z025017_1A_L1 - 2018-03-22 16.38.36_mask.png
# 159
# imgMode:/home/yxz1826/downsampled/8_group/17Z019474_1A_L12 - 2018-03-23 10.52.11.png
# 160
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z019474_1A_L12 - 2018-03-23 10.52.11_mask.png
# 161
# imgMode:/home/yxz1826/downsampled/8_group/17Z018721 1A L12.png
# 162
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018721 1A L12_mask.png
# 163
# imgMode:/home/yxz1826/downsampled/8_group/17Z017322 1A L123.png
# 164
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017322 1A L123_mask.png
# 165
# imgMode:/home/yxz1826/downsampled/8_group/17Z018731_1A_L123 - 2018-03-24 15.04.29.png
# 166
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018731_1A_L123 - 2018-03-24 15.04.29_mask.png
# 167
# imgMode:/home/yxz1826/downsampled/8_group/17S049631_1A_L123 - 2018-03-20 07.34.16.png
# 168
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049631_1A_L123 - 2018-03-20 07.34.16_mask.png
# 169
# imgMode:/home/yxz1826/downsampled/8_group/17Z023854_1A_L123 - 2018-03-23 13.27.59.png
# 170
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z023854_1A_L123 - 2018-03-23 13.27.59_mask.png
# 171
# imgMode:/home/yxz1826/downsampled/8_group/17Z024073_1A_L1 - 2018-03-22 17.40.08.png
# 172
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024073_1A_L1 - 2018-03-22 17.40.08_mask.png
# 173
# imgMode:/home/yxz1826/downsampled/8_group/17S050297_1A_L123 - 2018-03-21 14.25.05.png
# 174
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050297_1A_L123 - 2018-03-21 14.25.05_mask.png
# 175
# imgMode:/home/yxz1826/downsampled/8_group/17s050090_1A_L1 - 2018-03-20 12.26.02.png
# 176
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17s050090_1A_L1 - 2018-03-20 12.26.02_mask.png
# 177
# imgMode:/home/yxz1826/downsampled/8_group/17Z018725_1A_L123 - 2018-03-24 14.56.28.png
# 178
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018725_1A_L123 - 2018-03-24 14.56.28_mask.png
# 179
# imgMode:/home/yxz1826/downsampled/8_group/17Z017799_1A_L3 - 2018-03-23 17.36.08.png
# 180
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017799_1A_L3 - 2018-03-23 17.36.08_mask.png
# 181
# imgMode:/home/yxz1826/downsampled/8_group/17Z024647_1A_L123 - 2018-03-22 15.44.08.png
# 182
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024647_1A_L123 - 2018-03-22 15.44.08_mask.png
# 183
# imgMode:/home/yxz1826/downsampled/8_group/17Z033097_1A_L12 - 2018-03-26 17.18.22.png
# 184
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033097_1A_L12 - 2018-03-26 17.18.22_mask.png
# 185
# imgMode:/home/yxz1826/downsampled/8_group/17Z024649_2A_L123 - 2018-03-22 15.55.58.png
# 186
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024649_2A_L123 - 2018-03-22 15.55.58_mask.png
# 187
# imgMode:/home/yxz1826/downsampled/8_group/17Z024588_1A_L12 - 2018-03-22 17.06.01.png
# 188
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024588_1A_L12 - 2018-03-22 17.06.01_mask.png
# 189
# imgMode:/home/yxz1826/downsampled/8_group/17S051163_1A_L123 - 2018-03-20 15.23.56.png
# 190
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051163_1A_L123 - 2018-03-20 15.23.56_mask.png
# 191
# imgMode:/home/yxz1826/downsampled/8_group/17Z032937_1A_L1 - 2018-03-20 10.19.23.png
# 192
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032937_1A_L1 - 2018-03-20 10.19.23_mask.png
# 193
# imgMode:/home/yxz1826/downsampled/8_group/17S050094_1A_L1 - 2018-03-20 12.31.05.png
# 194
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050094_1A_L1 - 2018-03-20 12.31.05_mask.png
# 195
# imgMode:/home/yxz1826/downsampled/8_group/17Z025015_1A_L12 - 2018-03-22 16.32.05.png
# 196
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z025015_1A_L12 - 2018-03-22 16.32.05_mask.png
# 197
# imgMode:/home/yxz1826/downsampled/8_group/17S051557_1A_L123 - 2018-03-20 21.15.23.png
# 198
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051557_1A_L123 - 2018-03-20 21.15.23_mask.png
# 199
# imgMode:/home/yxz1826/downsampled/8_group/17S050297_5A_L123 - 2018-03-21 14.40.30.png
# 200
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050297_5A_L123 - 2018-03-21 14.40.30_mask.png
# 201
# imgMode:/home/yxz1826/downsampled/8_group/17Z032981_1A_L1 - 2018-03-26 17.08.08.png
# 202
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032981_1A_L1 - 2018-03-26 17.08.08_mask.png
# 203
# imgMode:/home/yxz1826/downsampled/8_group/17Z032901_2A_L123 - 2018-03-20 09.56.29.png
# 204
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032901_2A_L123 - 2018-03-20 09.56.29_mask.png
# 205
# imgMode:/home/yxz1826/downsampled/8_group/17Z023747_2A_L123 - 2018-03-23 13.07.31.png
# 206
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z023747_2A_L123 - 2018-03-23 13.07.31_mask.png
# 207
# imgMode:/home/yxz1826/downsampled/8_group/17S049923_1A_L12 - 2018-03-20 12.15.20.png
# 208
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049923_1A_L12 - 2018-03-20 12.15.20_mask.png
# 209
# imgMode:/home/yxz1826/downsampled/8_group/17S051538_1A_L12 - 2018-03-20 20.44.21.png
# 210
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051538_1A_L12 - 2018-03-20 20.44.21_mask.png
# 211
# imgMode:/home/yxz1826/downsampled/8_group/17s051042_2A_L123 - 2018-03-20 13.56.25.png
# 212
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17s051042_2A_L123 - 2018-03-20 13.56.25_mask.png
# 213
# imgMode:/home/yxz1826/downsampled/8_group/17S050002_1A_L12 - 2018-03-20 12.33.41.png
# 214
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050002_1A_L12 - 2018-03-20 12.33.41_mask.png
# 215
# imgMode:/home/yxz1826/downsampled/8_group/17Z032979_1A_L123 - 2018-03-26 16.56.33.png
# 216
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032979_1A_L123 - 2018-03-26 16.56.33_mask.png
# 217
# imgMode:/home/yxz1826/downsampled/8_group/17Z025021_1A_L123 - 2018-03-22 11.23.50.png
# 218
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z025021_1A_L123 - 2018-03-22 11.23.50_mask.png
# 219
# imgMode:/home/yxz1826/downsampled/8_group/17Z024405_1A_L123 - 2018-03-22 17.23.27.png
# 220
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024405_1A_L123 - 2018-03-22 17.23.27_mask.png
# 221
# imgMode:/home/yxz1826/downsampled/8_group/17S049736_1A_L12 - 2018-03-20 08.09.03.png
# 222
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049736_1A_L12 - 2018-03-20 08.09.03_mask.png
# 223
# imgMode:/home/yxz1826/downsampled/8_group/17Z017799_1A_L123 - 2018-03-23 17.34.11.png
# 224
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017799_1A_L123 - 2018-03-23 17.34.11_mask.png
# 225
# imgMode:/home/yxz1826/downsampled/8_group/17Z024395_1A_L123 - 2018-03-22 18.13.56.png
# 226
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024395_1A_L123 - 2018-03-22 18.13.56_mask.png
# 227
# imgMode:/home/yxz1826/downsampled/8_group/17Z024697_1A_L1 - 2018-03-22 16.15.55.png
# 228
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024697_1A_L1 - 2018-03-22 16.15.55_mask.png
# 229
# imgMode:/home/yxz1826/downsampled/8_group/17S049645_1A_L123 - 2018-03-20 07.45.26.png
# 230
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049645_1A_L123 - 2018-03-20 07.45.26_mask.png
# 231
# imgMode:/home/yxz1826/downsampled/8_group/17S050297_2A_12 - 2018-03-21 14.28.00.png
# 232
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050297_2A_12 - 2018-03-21 14.28.00_mask.png
# 233
# imgMode:/home/yxz1826/downsampled/8_group/17Z033104_1A_L123 - 2018-03-26 17.22.56.png
# 234
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033104_1A_L123 - 2018-03-26 17.22.56_mask.png
# 235
# imgMode:/home/yxz1826/downsampled/8_group/17S051312_1A_L123 - 2018-03-20 16.22.24.png
# 236
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051312_1A_L123 - 2018-03-20 16.22.24_mask.png
# 237
# imgMode:/home/yxz1826/downsampled/8_group/17s050294_3A_L12 - 2018-03-20 12.54.16.png
# 238
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17s050294_3A_L12 - 2018-03-20 12.54.16_mask.png
# 239
# imgMode:/home/yxz1826/downsampled/8_group/17S051236_1A_L12 - 2018-03-20 15.57.12.png
# 240
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051236_1A_L12 - 2018-03-20 15.57.12_mask.png
# 241
# imgMode:/home/yxz1826/downsampled/8_group/17Z019199_2A_L1 - 2018-03-23 10.26.58.png
# 242
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z019199_2A_L1 - 2018-03-23 10.26.58_mask.png
# 243
# imgMode:/home/yxz1826/downsampled/8_group/17Z024399_2A_L123 - 2018-03-22 18.31.18.png
# 244
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024399_2A_L123 - 2018-03-22 18.31.18_mask.png
# 245
# imgMode:/home/yxz1826/downsampled/8_group/17Z032903_1A_L12 - 2018-03-20 10.02.32.png
# 246
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032903_1A_L12 - 2018-03-20 10.02.32_mask.png
# 247
# imgMode:/home/yxz1826/downsampled/8_group/17z023746_2A_L123 - 2018-03-23 13.02.04.png
# 248
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z023746_2A_L123 - 2018-03-23 13.02.04_mask.png
# 249
# imgMode:/home/yxz1826/downsampled/8_group/17Z032978_2B_L12 - 2018-03-26 16.52.18.png
# 250
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032978_2B_L12 - 2018-03-26 16.52.18_mask.png
# 251
# imgMode:/home/yxz1826/downsampled/8_group/17S051235_1A_L123 - 2018-03-20 15.43.54.png
# 252
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051235_1A_L123 - 2018-03-20 15.43.54_mask.png
# 253
# imgMode:/home/yxz1826/downsampled/8_group/17Z018511_1A_L123 - 2018-03-24 14.12.32.png
# 254
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018511_1A_L123 - 2018-03-24 14.12.32_mask.png
# 255
# imgMode:/home/yxz1826/downsampled/8_group/17Z032862_1A_L123 - 2018-03-20 09.38.29.png
# 256
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032862_1A_L123 - 2018-03-20 09.38.29_mask.png
# 257
# imgMode:/home/yxz1826/downsampled/8_group/17S051389_1A_L123 - 2018-03-20 20.38.19.png
# 258
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051389_1A_L123 - 2018-03-20 20.38.19_mask.png
# 259
# imgMode:/home/yxz1826/downsampled/8_group/17Z018611_1A_L123 - 2018-03-23 11.35.49.png
# 260
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018611_1A_L123 - 2018-03-23 11.35.49_mask.png
# 261
# imgMode:/home/yxz1826/downsampled/8_group/17S050537_1A_L123 - 2018-03-21 15.09.01.png
# 262
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050537_1A_L123 - 2018-03-21 15.09.01_mask.png
# 263
# imgMode:/home/yxz1826/downsampled/8_group/17S049699_1A_L1 - 2018-03-20 08.04.40.png
# 264
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049699_1A_L1 - 2018-03-20 08.04.40_mask.png
# 265
# imgMode:/home/yxz1826/downsampled/8_group/17Z017052_1A_L123 - 2018-03-23 15.18.30.png
# 266
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017052_1A_L123 - 2018-03-23 15.18.30_mask.png
# 267
# imgMode:/home/yxz1826/downsampled/8_group/17S050556_2A_L123 - 2018-03-20 13.07.01.png
# 268
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050556_2A_L123 - 2018-03-20 13.07.01_mask.png
# 269
# imgMode:/home/yxz1826/downsampled/8_group/17S050297_7A_L123 - 2018-03-21 14.46.03.png
# 270
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050297_7A_L123 - 2018-03-21 14.46.03_mask.png
# 271
# imgMode:/home/yxz1826/downsampled/8_group/17Z018609_1A_L123 - 2018-03-23 11.19.52.png
# 272
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018609_1A_L123 - 2018-03-23 11.19.52_mask.png
# 273
# imgMode:/home/yxz1826/downsampled/8_group/17Z017036_1A_L123 - 2018-03-23 15.12.00.png
# 274
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017036_1A_L123 - 2018-03-23 15.12.00_mask.png
# 275
# imgMode:/home/yxz1826/downsampled/8_group/17Z024565_1A_STEP456 - 2018-03-22 16.55.40.png
# 276
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024565_1A_STEP456 - 2018-03-22 16.55.40_mask.png
# 277
# imgMode:/home/yxz1826/downsampled/8_group/17S049738_1A_L1 - 2018-03-20 08.12.02.png
# 278
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049738_1A_L1 - 2018-03-20 08.12.02_mask.png
# 279
# imgMode:/home/yxz1826/downsampled/8_group/17S049630_1A_L12 - 2018-03-20 07.25.16.png
# 280
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049630_1A_L12 - 2018-03-20 07.25.16_mask.png
# 281
# imgMode:/home/yxz1826/downsampled/8_group/17Z024091_1A_L12 - 2018-03-22 18.02.45.png
# 282
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024091_1A_L12 - 2018-03-22 18.02.45_mask.png
# 283
# imgMode:/home/yxz1826/downsampled/8_group/17Z024545_2A_L123 - 2018-03-22 16.47.53.png
# 284
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024545_2A_L123 - 2018-03-22 16.47.53_mask.png
# 285
# imgMode:/home/yxz1826/downsampled/8_group/17Z032936_3A_L12 - 2018-03-20 10.14.38.png
# 286
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032936_3A_L12 - 2018-03-20 10.14.38_mask.png
# 287
# imgMode:/home/yxz1826/downsampled/8_group/17S049741_1A_L1 - 2018-03-20 08.18.37.png
# 288
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049741_1A_L1 - 2018-03-20 08.18.37_mask.png
# 289
# imgMode:/home/yxz1826/downsampled/8_group/17Z032890_1A_L12 - 2018-03-20 09.43.55.png
# 290
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032890_1A_L12 - 2018-03-20 09.43.55_mask.png
# 291
# imgMode:/home/yxz1826/downsampled/8_group/17Z024763_1A_L123 - 2018-03-22 16.23.44.png
# 292
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024763_1A_L123 - 2018-03-22 16.23.44_mask.png
# 293
# imgMode:/home/yxz1826/downsampled/8_group/17Z024109_1A_L1 - 2018-03-22 18.05.53.png
# 294
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024109_1A_L1 - 2018-03-22 18.05.53_mask.png
# 295
# imgMode:/home/yxz1826/downsampled/8_group/17Z023980_1A_L1 - 2018-03-22 17.56.38.png
# 296
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z023980_1A_L1 - 2018-03-22 17.56.38_mask.png
# 297
# imgMode:/home/yxz1826/downsampled/8_group/17Z017350_1A_L12 - 2018-03-23 17.21.10.png
# 298
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017350_1A_L12 - 2018-03-23 17.21.10_mask.png
# 299
# imgMode:/home/yxz1826/downsampled/8_group/17Z017797_1A_L123 - 2018-03-23 17.25.43.png
# 300
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017797_1A_L123 - 2018-03-23 17.25.43_mask.png
# 301
# imgMode:/home/yxz1826/downsampled/8_group/17S049745_2A_L2 - 2018-03-20 11.11.04.png
# 302
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049745_2A_L2 - 2018-03-20 11.11.04_mask.png
# 303
# imgMode:/home/yxz1826/downsampled/8_group/17Z033103_1A_L123 - 2018-03-26 17.28.00.png
# 304
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033103_1A_L123 - 2018-03-26 17.28.00_mask.png
# 305
# imgMode:/home/yxz1826/downsampled/8_group/17Z024652_1A_L123 - 2018-03-22 16.10.27.png
# 306
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024652_1A_L123 - 2018-03-22 16.10.27_mask.png
# 307
# imgMode:/home/yxz1826/downsampled/8_group/17Z018510_1A_L123 - 2018-03-24 14.09.44.png
# 308
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018510_1A_L123 - 2018-03-24 14.09.44_mask.png
# 309
# imgMode:/home/yxz1826/downsampled/8_group/17Z024395_1A_STEP456 - 2018-03-22 18.16.42.png
# 310
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024395_1A_STEP456 - 2018-03-22 18.16.42_mask.png
# 311
# imgMode:/home/yxz1826/downsampled/8_group/17Z023747_1A_L123 - 2018-03-23 13.04.38.png
# 312
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z023747_1A_L123 - 2018-03-23 13.04.38_mask.png
# 313
# imgMode:/home/yxz1826/downsampled/8_group/17Z033116_1A_L123 - 2018-03-27 15.42.00.png
# 314
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033116_1A_L123 - 2018-03-27 15.42.00_mask.png
# 315
# imgMode:/home/yxz1826/downsampled/8_group/17Z024542_1A_STEP456 - 2018-03-22 17.37.25.png
# 316
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024542_1A_STEP456 - 2018-03-22 17.37.25_mask.png
# 317
# imgMode:/home/yxz1826/downsampled/8_group/17Z032840_1A_L12 - 2018-03-20 09.32.58.png
# 318
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032840_1A_L12 - 2018-03-20 09.32.58_mask.png
# 319
# imgMode:/home/yxz1826/downsampled/8_group/17S049738_1A_L2 - 2018-03-20 08.15.20.png
# 320
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049738_1A_L2 - 2018-03-20 08.15.20_mask.png
# 321
# imgMode:/home/yxz1826/downsampled/8_group/17S050297_3A_ff - 2018-03-21 14.34.41.png
# 322
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050297_3A_ff - 2018-03-21 14.34.41_mask.png
# 323
# imgMode:/home/yxz1826/downsampled/8_group/17S050093_1A_L1 - 2018-03-20 12.27.58.png
# 324
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050093_1A_L1 - 2018-03-20 12.27.58_mask.png
# 325
# imgMode:/home/yxz1826/downsampled/8_group/17Z032900_1A_L1 - 2018-03-20 09.46.24.png
# 326
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032900_1A_L1 - 2018-03-20 09.46.24_mask.png
# 327
# imgMode:/home/yxz1826/downsampled/8_group/17S050373_1A_123 - 2018-03-21 14.48.41.png
# 328
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050373_1A_123 - 2018-03-21 14.48.41_mask.png
# 329
# imgMode:/home/yxz1826/downsampled/8_group/17S049745_2A_L1 - 2018-03-20 11.07.15.png
# 330
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049745_2A_L1 - 2018-03-20 11.07.15_mask.png
# 331
# imgMode:/home/yxz1826/downsampled/8_group/17Z024587_1A_L1 - 2018-03-22 17.03.48.png
# 332
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024587_1A_L1 - 2018-03-22 17.03.48_mask.png
# 333
# imgMode:/home/yxz1826/downsampled/8_group/17Z018506_2A_L123 - 2018-03-24 14.02.17.png
# 334
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018506_2A_L123 - 2018-03-24 14.02.17_mask.png
# 335
# imgMode:/home/yxz1826/downsampled/8_group/17Z024545_1A_L123 - 2018-03-22 16.45.04.png
# 336
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024545_1A_L123 - 2018-03-22 16.45.04_mask.png
# 337
# imgMode:/home/yxz1826/downsampled/8_group/17S049641_2A_L123 - 2018-03-20 07.41.52.png
# 338
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049641_2A_L123 - 2018-03-20 07.41.52_mask.png
# 339
# imgMode:/home/yxz1826/downsampled/8_group/17s050299_1A_L12 - 2018-03-20 12.41.07.png
# 340
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17s050299_1A_L12 - 2018-03-20 12.41.07_mask.png
# 341
# imgMode:/home/yxz1826/downsampled/8_group/17Z018727_1A_L123 - 2018-03-24 14.59.07.png
# 342
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018727_1A_L123 - 2018-03-24 14.59.07_mask.png
# 343
# imgMode:/home/yxz1826/downsampled/8_group/17Z024402_1A_L123 - 2018-03-22 17.15.26.png
# 344
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024402_1A_L123 - 2018-03-22 17.15.26_mask.png
# 345
# imgMode:/home/yxz1826/downsampled/8_group/17z024650_4A_L12 - 2018-03-22 16.07.26.png
# 346
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z024650_4A_L12 - 2018-03-22 16.07.26_mask.png
# 347
# imgMode:/home/yxz1826/downsampled/8_group/17S049755_1A_L12 - 2018-03-20 11.19.17.png
# 348
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049755_1A_L12 - 2018-03-20 11.19.17_mask.png
# 349
# imgMode:/home/yxz1826/downsampled/8_group/17z023746_3A_L123 - 2018-03-23 12.59.14.png
# 350
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17z023746_3A_L123 - 2018-03-23 12.59.14_mask.png
# 351
# imgMode:/home/yxz1826/downsampled/8_group/17S050296_1A_L123 - 2018-03-20 13.01.18.png
# 352
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050296_1A_L123 - 2018-03-20 13.01.18_mask.png
# 353
# imgMode:/home/yxz1826/downsampled/8_group/17S049755_2A_L12 - 2018-03-20 11.21.38.png
# 354
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S049755_2A_L12 - 2018-03-20 11.21.38_mask.png
# 355
# imgMode:/home/yxz1826/downsampled/8_group/17Z032980_1A_L1 - 2018-03-26 17.03.51.png
# 356
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032980_1A_L1 - 2018-03-26 17.03.51_mask.png
# 357
# imgMode:/home/yxz1826/downsampled/8_group/17Z024698_2A_L123 - 2018-03-22 16.21.07.png
# 358
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024698_2A_L123 - 2018-03-22 16.21.07_mask.png
# 359
# imgMode:/home/yxz1826/downsampled/8_group/17Z032978_1A_L12 - 2018-03-26 16.45.53.png
# 360
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z032978_1A_L12 - 2018-03-26 16.45.53_mask.png
# 361
# imgMode:/home/yxz1826/downsampled/8_group/17Z033111_1A_L123 - 2018-03-27 15.25.35.png
# 362
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033111_1A_L123 - 2018-03-27 15.25.35_mask.png
# 363
# imgMode:/home/yxz1826/downsampled/8_group/17Z024073_1B_L1 - 2018-03-22 17.43.06.png
# 364
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024073_1B_L1 - 2018-03-22 17.43.06_mask.png
# /numpixels (CArray(2, 4)) ''
# val
# 1
# imgMode:/home/yxz1826/downsampled/8_group/17S051334_1A_L12 - 2018-03-20 16.38.24.png
# 2
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051334_1A_L12 - 2018-03-20 16.38.24_mask.png
# 3
# imgMode:/home/yxz1826/downsampled/8_group/17S050297_6A_L123 - 2018-03-21 14.43.11.png
# 4
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050297_6A_L123 - 2018-03-21 14.43.11_mask.png
# 5
# imgMode:/home/yxz1826/downsampled/8_group/17Z024498_2A_L123 - 2018-03-22 18.23.14.png
# 6
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024498_2A_L123 - 2018-03-22 18.23.14_mask.png
# 7
# imgMode:/home/yxz1826/downsampled/8_group/17Z024066_1A_L123 - 2018-03-23 13.53.03.png
# 8
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024066_1A_L123 - 2018-03-23 13.53.03_mask.png
# 9
# imgMode:/home/yxz1826/downsampled/8_group/17s051235_2A_L456 - 2018-03-20 15.49.17.png
# 10
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17s051235_2A_L456 - 2018-03-20 15.49.17_mask.png
# 11
# imgMode:/home/yxz1826/downsampled/8_group/17S051329_1A_L12 - 2018-03-20 16.32.00.png
# 12
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051329_1A_L12 - 2018-03-20 16.32.00_mask.png
# 13
# imgMode:/home/yxz1826/downsampled/8_group/17Z025018_1A_L123 - 2018-03-22 11.12.21.png
# 14
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z025018_1A_L123 - 2018-03-22 11.12.21_mask.png
# 15
# imgMode:/home/yxz1826/downsampled/8_group/17Z024649_1A_L1 - 2018-03-22 15.47.44.png
# 16
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024649_1A_L1 - 2018-03-22 15.47.44_mask.png
# 17
# imgMode:/home/yxz1826/downsampled/8_group/17Z017278 1A L123.png
# 18
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z017278 1A L123_mask.png
# 19
# imgMode:/home/yxz1826/downsampled/8_group/17Z033042_1A_L12 - 2018-03-26 17.10.41.png
# 20
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033042_1A_L12 - 2018-03-26 17.10.41_mask.png
# 21
# imgMode:/home/yxz1826/downsampled/8_group/17S051235_2A_L123 - 2018-03-20 15.51.57.png
# 22
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051235_2A_L123 - 2018-03-20 15.51.57_mask.png
# 23
# imgMode:/home/yxz1826/downsampled/8_group/17Z024399_3A_L123 - 2018-03-22 18.34.06.png
# 24
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024399_3A_L123 - 2018-03-22 18.34.06_mask.png
# 25
# imgMode:/home/yxz1826/downsampled/8_group/17Z024540_1A_L123 - 2018-03-22 17.31.34.png
# 26
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024540_1A_L123 - 2018-03-22 17.31.34_mask.png
# 27
# imgMode:/home/yxz1826/downsampled/8_group/17S050290_1A_L12 - 2018-03-20 12.44.10.png
# 28
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S050290_1A_L12 - 2018-03-20 12.44.10_mask.png
# 29
# imgMode:/home/yxz1826/downsampled/8_group/17Z018506_1A_L123 - 2018-03-24 13.58.49.png
# 30
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z018506_1A_L123 - 2018-03-24 13.58.49_mask.png
# 31
# imgMode:/home/yxz1826/downsampled/8_group/17Z025020_1A_L123 - 2018-03-22 11.21.07.png
# 32
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z025020_1A_L123 - 2018-03-22 11.21.07_mask.png
# 33
# imgMode:/home/yxz1826/downsampled/8_group/17Z024401_1A_L1 - 2018-03-22 17.12.06.png
# 34
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024401_1A_L1 - 2018-03-22 17.12.06_mask.png
# 35
# imgMode:/home/yxz1826/downsampled/8_group/17Z033111_2B_L123 - 2018-03-27 08.48.59.png
# 36
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z033111_2B_L123 - 2018-03-27 08.48.59_mask.png
# 37
# imgMode:/home/yxz1826/downsampled/8_group/17S051562_1A_L12 - 2018-03-20 09.27.47.png
# 38
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17S051562_1A_L12 - 2018-03-20 09.27.47_mask.png
# 39
# imgMode:/home/yxz1826/downsampled/8_group/17Z024068_1A_L456 - 2018-03-23 13.58.45.png
# 40
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024068_1A_L456 - 2018-03-23 13.58.45_mask.png
# 41
# imgMode:/home/yxz1826/downsampled/8_group/17Z024542_1A_L123 - 2018-03-22 17.34.27.png
# 42
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024542_1A_L123 - 2018-03-22 17.34.27_mask.png
# /numpixels (CArray(2, 4)) ''

# %%
#useful reference
#http://machinelearninguru.com/deep_learning/data_preparation/hdf5/hdf5.html

# %%
print(f"{pytable_root}/{dataname}_{phase}.pytable")
# Out:
# /mnt/ccipd_home/yxz1826/Skin/pytable/melanoma_png_8_val.pytable

# %%
phase
# Out:
# 'val'

# %%
phases
# Out:
# {'train': array([110, 153,  38,  29,  44,  83,  64,  57, 194, 179,  97,  32,  62,
#         176,  74,  81,   6, 101, 128, 201,  22, 200,  88, 183,  34, 151,
#         173,  13,  46,   5,  31,  25,  48, 124, 188,  77, 150,  69,  50,
#         100, 193,  98, 103, 147,   7, 162,  14, 154, 142,  15,  40,  56,
#         122,  78, 159, 118, 112, 172,  89, 181,  65, 186,   1,  17, 163,
#          18,  27, 171, 135, 161,  66,  95,  20, 182, 184, 185, 169,  99,
#          92, 140,  39,  85, 175, 158, 178,  93, 192, 160,  10, 165, 105,
#         109, 115, 166, 138, 125,  53,  91,  71, 116, 157,  96,  21,   4,
#         139, 149,  63, 137,  51,  60, 174,  52, 197,  19,  37,  36, 120,
#          28, 189, 121, 190,  73,  72,  80,  87,  45,  76,  59, 129, 199,
#         143,  33,  79, 102, 177,  16,   0, 114, 156, 146, 108, 127, 132,
#           3, 196,  47,  70, 144, 111, 155, 198,  43, 195,  67,  23, 202,
#          41, 104, 107, 119, 134, 152, 148, 170, 126, 136,  86,  30,  55,
#         113, 180,  12, 164,  58,  68, 130, 191,  35, 167, 145,   9,  82]),
#  'val': array([ 54, 131, 123,  42,   2,  61, 141, 117, 106,  11,  94,  24,  90,
#         187,  84,   8, 168,  26, 133,  75,  49])}

# %%
testcreate = tables.open_file("/mnt/ccipd_home/yxz1826/Skin/pytable/melanoma_png_test_val.pytable",mode='w')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-a38517a3885a> in <module>()
# ----> 1 testcreate = tables.open_file("/mnt/ccipd_home/yxz1826/Skin/pytable/melanoma_png_test_val.pytable",mode='w')
#
# /usr/local/lib/python3.6/site-packages/tables/file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     318
#     319     # Finally, create the File instance, and return it
# --> 320     return File(filename, mode, title, root_uep, filters, **kwargs)
#     321
#     322
#
# /usr/local/lib/python3.6/site-packages/tables/file.py in __init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     782
#     783         # Now, it is time to initialize the File extension
# --> 784         self._g_new(filename, mode, **params)
#     785
#     786         # Check filters and set PyTables format version for new files.
#
# tables/hdf5extension.pyx in tables.hdf5extension.File._g_new()
#
# /usr/local/lib/python3.6/site-packages/tables/utils.py in check_file_access(filename, mode)
#     178             if not os.access(parentname, os.W_OK):
#     179                 raise IOError("directory ``%s`` exists but it can not be "
# --> 180                               "written" % (parentname,))
#     181     elif mode == 'a':
#     182         if os.access(filename, os.F_OK):
#
# OSError: directory ``/mnt/ccipd_home/yxz1826/Skin/pytable`` exists but it can not be written

# %%
test = imageIOAdaptor('mask',imgdir,fname,file_ext,classes,(targetMag,baseMag),totals)
# Out:
# maskMode:/mnt/ccipd_home/yxz1826/Skin/QupathOut/multi_mag/8.0/17Z024763_2A_L123 - 2018-03-22 16.26.20_mask.png

# %%
test.max()
# Out:
# 3

# %%
test.shape
# Out:
# (8601, 32256)

# %%
io.max()
# Out:
# 3
